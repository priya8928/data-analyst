# %% [markdown]
# # Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as mp

# %% [markdown]
# ## Import the dataset

# %%
data = pd.read_csv('10000 Sales Records.csv')
sales_data = data.copy()
sales_data.head()
# Out:
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#          Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 0  Office Supplies        Online              L   1/27/2011  292494523
# 1        Beverages        Online              C  12/28/2015  361825549
# 2       Vegetables       Offline              C   1/13/2011  141515767
# 3        Household        Online              C   9/11/2012  500364005
# 4        Beverages        Online              C  10/27/2015  127481591
#
#    Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0  2/12/2011        4484      651.21     524.96     2920025.64  2353920.64
# 1  1/23/2016        1075       47.45      31.79       51008.75    34174.25
# 2   2/1/2011        6515      154.06      90.93     1003700.90   592408.95
# 3  10/6/2012        7683      668.27     502.54     5134318.41  3861014.82
# 4  12/5/2015        3491       47.45      31.79      165647.95   110978.89
#
#    Total Profit
# 0     566105.00
# 1      16834.50
# 2     411291.95
# 3    1273303.59
# 4      54669.06

# %%
sales_data = sales_data[["Order ID","Order Date","Order Priority","Ship Date","Item Type","Region","Country","Sales Channel","Units Sold","Unit Price","Unit Cost","Total Revenue","Total Cost","Total Profit"]]

# %%
sales_data.head()
# Out:
#     Order ID  Order Date Order Priority   Ship Date        Item Type  \
# 0  669165933   5/28/2010              H   6/27/2010        Baby Food
# 1  963881480   8/22/2012              C   9/15/2012           Cereal
# 2  341417157  05-02-2014              L  05-08-2014  Office Supplies
# 3  514321792   6/20/2014              C  07-05-2014           Fruits
# 4  115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                               Region                Country Sales Channel  \
# 0              Australia and Oceania                 Tuvalu       Offline
# 1  Central America and the Caribbean                Grenada        Online
# 2                             Europe                 Russia       Offline
# 3                 Sub-Saharan Africa  Sao Tome and Principe        Online
# 4                 Sub-Saharan Africa                 Rwanda       Offline
#
#    Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0        9925      255.28     159.42     2533654.00  1582243.50     951410.50
# 1        2804      205.70     117.11      576782.80   328376.44     248406.36
# 2        1779      651.21     524.96     1158502.59   933903.84     224598.75
# 3        8102        9.33       6.92       75591.66    56065.84      19525.82
# 4        5062      651.21     524.96     3296425.02  2657347.52     639077.50

# %%
sales_data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Ship Date', 'Item Type',
#        'Region', 'Country', 'Sales Channel', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales_data.axes[0]
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
sales_data.axes[1]
# Out:
# Index(['Order ID', 'Order Date', 'Order Priority', 'Ship Date', 'Item Type',
#        'Region', 'Country', 'Sales Channel', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales_data.dtypes
# Out:
# Order ID            int64
# Order Date         object
# Order Priority     object
# Ship Date          object
# Item Type          object
# Region             object
# Country            object
# Sales Channel      object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
sales_data.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
sales_data.head()
# Out:
#     Order ID  Order Date Order Priority  Ship Date        Item Type  \
# 0  292494523   1/27/2011              L  2/12/2011  Office Supplies
# 1  361825549  12/28/2015              C  1/23/2016        Beverages
# 2  141515767   1/13/2011              C   2/1/2011       Vegetables
# 3  500364005   9/11/2012              C  10/6/2012        Household
# 4  127481591  10/27/2015              C  12/5/2015        Beverages
#
#                          Region                           Country  \
# 0            Sub-Saharan Africa                              Chad
# 1                        Europe                            Latvia
# 2  Middle East and North Africa                          Pakistan
# 3            Sub-Saharan Africa  Democratic Republic of the Congo
# 4                        Europe                    Czech Republic
#
#   Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0        Online        4484      651.21     524.96     2920025.64  2353920.64
# 1        Online        1075       47.45      31.79       51008.75    34174.25
# 2       Offline        6515      154.06      90.93     1003700.90   592408.95
# 3        Online        7683      668.27     502.54     5134318.41  3861014.82
# 4        Online        3491       47.45      31.79      165647.95   110978.89
#
#    Total Profit
# 0     566105.00
# 1      16834.50
# 2     411291.95
# 3    1273303.59
# 4      54669.06

# %%
sales_data.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False])

# %%
sales_data.loc[:,["Total Revenue","Total Profit"]].iloc[:]
# Out:
#    Total Revenue  Total Profit
# 1       51008.75       16834.5

# %%
sales_data.shape
# Out:
# (10000, 14)

# %%
np.corrcoef(sales_data.loc[:,'Total Revenue'].iloc[:],sales_data.loc[:,'Total Profit'].iloc[:])
# Out:
# array([[1.        , 0.88201154],
#        [0.88201154, 1.        ]])

# %%
sales_data.set_index('Order ID',inplace=True)

# %%
sales_data.index
# Out:
# Int64Index([292494523, 361825549, 141515767, 500364005, 127481591, 482292354,
#             844532620, 564251220, 411809480, 327881228,
#             ...
#             651942288, 579082763, 521562898, 420056521, 735549962, 199342048,
#             763044106, 848579967, 298185956, 824410903],
#            dtype='int64', name='Order ID', length=10000)

# %%
sales_data.head()
# Out:
#            Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 292494523   1/27/2011              L  2/12/2011  Office Supplies
# 361825549  12/28/2015              C  1/23/2016        Beverages
# 141515767   1/13/2011              C   2/1/2011       Vegetables
# 500364005   9/11/2012              C  10/6/2012        Household
# 127481591  10/27/2015              C  12/5/2015        Beverages
#
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 292494523        Online        4484      651.21     524.96     2920025.64
# 361825549        Online        1075       47.45      31.79       51008.75
# 141515767       Offline        6515      154.06      90.93     1003700.90
# 500364005        Online        7683      668.27     502.54     5134318.41
# 127481591        Online        3491       47.45      31.79      165647.95
#
#            Total Cost  Total Profit
# Order ID
# 292494523  2353920.64     566105.00
# 361825549    34174.25      16834.50
# 141515767   592408.95     411291.95
# 500364005  3861014.82    1273303.59
# 127481591   110978.89      54669.06

# %%
sales_data.cov()
# Out:
# <ipython-input-24-03efbe4ea83a>:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_data.cov()
#                  Units Sold    Unit Price     Unit Cost  Total Revenue  \
# Units Sold     8.255545e+06 -8.127166e+03 -6.307254e+03   2.183049e+09
# Unit Price    -8.127166e+03  4.749963e+04  3.792942e+04   2.341145e+08
# Unit Cost     -6.307254e+03  3.792942e+04  3.113316e+04   1.869631e+08
# Total Revenue  2.183049e+09  2.341145e+08  1.869631e+08   2.146302e+12
# Total Cost     1.534886e+09  1.871199e+08  1.536326e+08   1.658436e+12
# Total Profit   6.481622e+08  4.699465e+07  3.333050e+07   4.878652e+11
#
#                  Total Cost  Total Profit
# Units Sold     1.534886e+09  6.481622e+08
# Unit Price     1.871199e+08  4.699465e+07
# Unit Cost      1.536326e+08  3.333050e+07
# Total Revenue  1.658436e+12  4.878652e+11
# Total Cost     1.313119e+12  3.453174e+11
# Total Profit   3.453174e+11  1.425477e+11

# %%
sales_data.corr(method='pearson')
# Out:
# <ipython-input-27-7935e9da15c5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_data.corr(method='pearson')
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000   -0.012978  -0.012441       0.518615    0.466178
# Unit Price      -0.012978    1.000000   0.986324       0.733226    0.749243
# Unit Cost       -0.012441    0.986324   1.000000       0.723267    0.759836
# Total Revenue    0.518615    0.733226   0.723267       1.000000    0.987874
# Total Cost       0.466178    0.749243   0.759836       0.987874    1.000000
# Total Profit     0.597490    0.571114   0.500323       0.882012    0.798153
#
#                Total Profit
# Units Sold         0.597490
# Unit Price         0.571114
# Unit Cost          0.500323
# Total Revenue      0.882012
# Total Cost         0.798153
# Total Profit       1.000000

# %% [markdown]
# #### The high value of Pearson correlation coefficient between Total Revenue and Total Profit indicates that these two variables are closely related to each other.
# #### If revenue generated is high, then more profit will be generated and vice versa.
# #### The negative value of correlation coefficient among Units Sold and Unit Cost implies that quantity of products is inversely proportional to their cost. Same is the scenario with Units Sold and Units Price. Lesser the number of units of a product available, more will be it's price.

# %%
np.average(sales_data['Total Profit'])
# Out:
# 395089.347193

# %% [markdown]
# #### At an average, the profit generated for a product is ₹441681.98.

# %%
np.max(sales_data['Total Profit'])
# Out:
# 1738178.39

# %%
np.min(sales_data['Total Profit'])
# Out:
# 43.38

# %%
np.var(sales_data['Total Profit'])
# Out:
# 142533493603.36465

# %% [markdown]
# #### Maximum and minimum profit generated are ₹ 1719922.04 and ₹ 1258.09 respectively.

# %% [markdown]
# ## Let's study total revenue

# %%
np.max(sales_data['Total Revenue'])
# Out:
# 6680026.92

# %%
np.min(sales_data['Total Revenue'])
# Out:
# 167.94

# %%
np.mean(sales_data['Total Revenue'])
# Out:
# 1333355.131432

# %%
np.var(sales_data['Total Revenue'])
# Out:
# 2146087060140.8992

# %%
np.std(sales_data['Total Revenue'])
# Out:
# 1464952.9207933268

# %%
np.median(sales_data['Total Revenue'])
# Out:
# 800051.21

# %%
np.percentile(sales_data['Total Revenue'],50,axis=0,overwrite_input=True)
# Out:
# 800051.21

# %% [markdown]
# ### Maximum and minimum revenue generated by the product are ₹ 5997054.98 and ₹ 4870.26.

# %% [markdown]
# ### Revenue has very high variability in it's distribution. The median revenue generated is ₹ 752314.36.

# %%
mp.scatter(sales_data['Total Profit'],sales_data['Total Revenue'])

# %% [markdown]
# #### The scatter plot also suggests that total profit and total revenue are directly proportional to each other.

# %%
mp.hist(sales_data['Total Revenue'])
# Out:
# (array([4455., 2172., 1154.,  638.,  398.,  381.,  299.,  192.,  170.,
#          141.]),
#  array([1.67940000e+02, 6.68153838e+05, 1.33613974e+06, 2.00412563e+06,
#         2.67211153e+06, 3.34009743e+06, 4.00808333e+06, 4.67606923e+06,
#         5.34405512e+06, 6.01204102e+06, 6.68002692e+06]),
#  <BarContainer object of 10 artists>)

# %%
np.correlate(sales_data['Total Revenue'],sales_data['Total Profit'])
# Out:
# array([5.4086542e+15])

# %%
sales_data.head()
# Out:
#            Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 292494523   1/27/2011              L  2/12/2011  Office Supplies
# 361825549  12/28/2015              C  1/23/2016        Beverages
# 141515767   1/13/2011              C   2/1/2011       Vegetables
# 500364005   9/11/2012              C  10/6/2012        Household
# 127481591  10/27/2015              C  12/5/2015        Beverages
#
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 292494523        Online        4484      651.21     524.96         167.94
# 361825549        Online        1075       47.45      31.79      308633.52
# 141515767       Offline        6515      154.06      90.93       51008.75
# 500364005        Online        7683      668.27     502.54       41369.22
# 127481591        Online        3491       47.45      31.79       17556.50
#
#            Total Cost  Total Profit
# Order ID
# 292494523  2353920.64     566105.00
# 361825549    34174.25      16834.50
# 141515767   592408.95     411291.95
# 500364005  3861014.82    1273303.59
# 127481591   110978.89      54669.06

# %%
np.histogram(sales_data['Total Cost'],bins=10)
# Out:
# (array([5234, 1972,  849,  466,  438,  253,  316,  171,  173,  128]),
#  array([1.24560000e+02, 5.24284664e+05, 1.04844477e+06, 1.57260487e+06,
#         2.09676498e+06, 2.62092508e+06, 3.14508518e+06, 3.66924529e+06,
#         4.19340539e+06, 4.71756550e+06, 5.24172560e+06]))

# %%
mp.hist(sales_data['Total Cost'],bins=20)
# Out:
# (array([3489., 1745., 1131.,  841.,  481.,  368.,  244.,  222.,  216.,
#          222.,  125.,  128.,  159.,  157.,   80.,   91.,   97.,   76.,
#           78.,   50.]),
#  array([1.24560000e+02, 2.62204612e+05, 5.24284664e+05, 7.86364716e+05,
#         1.04844477e+06, 1.31052482e+06, 1.57260487e+06, 1.83468492e+06,
#         2.09676498e+06, 2.35884503e+06, 2.62092508e+06, 2.88300513e+06,
#         3.14508518e+06, 3.40716524e+06, 3.66924529e+06, 3.93132534e+06,
#         4.19340539e+06, 4.45548544e+06, 4.71756550e+06, 4.97964555e+06,
#         5.24172560e+06]),
#  <BarContainer object of 20 artists>)

# %%
sales_data.corr(method='pearson')
# Out:
# <ipython-input-49-7935e9da15c5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sales_data.corr(method='pearson')
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000   -0.012978  -0.012441       0.014473    0.466178
# Unit Price      -0.012978    1.000000   0.986324       0.015151    0.749243
# Unit Cost       -0.012441    0.986324   1.000000       0.013599    0.759836
# Total Revenue    0.014473    0.015151   0.013599       1.000000    0.026955
# Total Cost       0.466178    0.749243   0.759836       0.026955    1.000000
# Total Profit     0.597490    0.571114   0.500323       0.025442    0.798153
#
#                Total Profit
# Units Sold         0.597490
# Unit Price         0.571114
# Unit Cost          0.500323
# Total Revenue      0.025442
# Total Cost         0.798153
# Total Profit       1.000000

# %%
mp.scatter(sales_data['Units Sold'],sales_data['Unit Cost'])

# %% [markdown]
# #### The above scatter plot implies that the two variables 'Units Sold' and 'Unit Cost' are inversely proportional to each other to some extent. When more units of a product are sold, the unit cost of that product becomes lesser and vice versa.

# %%
sales_data.plot.line(x='Units Sold',y='Total Cost',subplots=True,color={'Total Cost': 'yellow'})
# Out:
# array([<Axes: xlabel='Units Sold'>], dtype=object)

# %%
mp.hist(sales_data['Unit Cost'])
# Out:
# (array([3337., 1652., 1667.,    0.,  834.,    0.,  798.,    0.,    0.,
#         1712.]),
#  array([  6.92 ,  58.724, 110.528, 162.332, 214.136, 265.94 , 317.744,
#         369.548, 421.352, 473.156, 524.96 ]),
#  <BarContainer object of 10 artists>)

# %%
np.min(sales_data['Unit Cost'])
# Out:
# 6.92

# %%
np.max(sales_data['Unit Cost'])
# Out:
# 524.96

# %%
np.mean(sales_data['Unit Cost'])
# Out:
# 188.80663900000002

# %%
np.std(sales_data['Unit Cost'])
# Out:
# 176.43708421438416

# %%
np.var(sales_data['Unit Cost'])
# Out:
# 31130.044686073685

# %%
np.median(sales_data['Unit Cost'])
# Out:
# 117.11

# %% [markdown]
# #### Maximum and minimum unit costs are ₹ 6.92 and ₹ 524.96 respectively. Average unit cost of a product is ₹ 191.05. The Unit Cost variable varies considerably throughout it's distribution. The median cost of a unit stands at ₹ 107.28.

# %%
area_plot = sales_data.plot.area(x='Unit Price',y='Total Profit',color='pink',stacked=True,legend=None)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Maximum profit has been generated in the unit price range of ₹400-₹500.

# %%
sales_data.plot.area(x='Units Sold',y='Total Profit',color='purple',legend=None)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Maximum profit has been generated when the number of units sold were between 8000 and 10000 i.e. more the number of units sold, more will be the profit generated.

# %%
sales_data.plot.area(x='Units Sold',y='Total Cost',color='aqua',legend=None)
mp.ylabel('Total Cost')
# Out:
# Text(0, 0.5, 'Total Cost')

# %% [markdown]
# ### Maximum cost has been generated when 8000-9000 units were sold.

# %%
sales_data.plot.area(x='Units Sold',y='Total Revenue',color='grey',legend=None)
mp.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')

# %% [markdown]
# ### Maximum revenue has been generated when 5000-6500 units of a product were sold.

# %%
bar_plot = sales_data.plot.bar(x='Units Sold',y=['Total Revenue','Total Cost','Total Profit'],color=['purple','red','blue'],stacked=True,rot=True)
mp.xticks(rotation=90)
mp.locator_params(nbins=38)
mp.tick_params(axis='y', which='major', labelsize=7)

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
sales_data.plot.barh(x='Item Type',y='Total Revenue',color='blue')
mp.locator_params(nbins=28)
mp.xlabel('Total Revenue')
# Out:
# Text(0.5, 0, 'Total Revenue')

# %%
sales_data['Item Type'].unique()
# Out:
# array(['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
#        'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
#        'Meat', 'Snacks'], dtype=object)

# %%
items = ['Baby Food', 'Cereal', 'Office Supplies', 'Fruits', 'Household',
       'Vegetables', 'Personal Care', 'Clothes', 'Cosmetics', 'Beverages',
       'Meat', 'Snacks']

# %%
sales_data['Item Type'] = pd.Categorical(sales_data['Item Type'],categories=items,ordered=True)

# %%
sales_data.groupby('Item Type')['Total Revenue'].count().plot(kind='bar',color=['green','orange','blue','red','purple','pink','yellow','brown','aqua','grey'])
# Out:
# <AxesSubplot:xlabel='Item Type'>

# %%
pd.pivot_table(sales_data,values='Total Revenue',index='Item Type',aggfunc='count').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Item Type'>

# %% [markdown]
# ### Maximum revenue has been generated from the items 'Clothes' and 'Cosmetics' closely followed by 'Office Supplies'.

# %%
#pd.pivot_table(sales_data,values=['Total Revenue','Total Cost','Total Profit'],index='Units Sold',aggfunc='count').plot(kind='kde',color=['green','orange','red'],stacked=True)
pd.pivot_table(sales_data,index='Units Sold',aggfunc='count').plot(kind='kde',stacked=True,legend=None)
mp.xlabel('Units Sold')
# Out:
# Text(0.5, 0, 'Units Sold')

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
sales_data.loc[:,'Order Priority'].unique()
# Out:
# array(['H', 'C', 'L', 'M'], dtype=object)

# %%
sales_data['Order Date'].unique()
# Out:
# array(['5/28/2010', '8/22/2012', '05-02-2014', '6/20/2014', '02-01-2013',
#        '02-04-2015', '4/23/2011', '7/17/2012', '7/14/2015', '4/18/2014',
#        '6/24/2011', '08-02-2014', '1/13/2017', '02-08-2017', '2/19/2014',
#        '4/23/2012', '11/19/2016', '04-01-2015', '12/30/2010', '7/31/2012',
#        '5/14/2014', '7/31/2015', '6/30/2016', '09-08-2014', '05-07-2016',
#        '5/22/2017', '10/13/2014', '05-07-2010', '7/18/2014', '5/26/2012',
#        '9/17/2012', '12/29/2013', '10/27/2015', '1/16/2015', '2/25/2017',
#        '05-08-2017', '11/22/2011', '1/14/2017', '04-01-2012', '2/16/2012',
#        '03-11-2017', '02-06-2010', '06-07-2012', '10-06-2012',
#        '11/14/2015', '3/29/2016', '12/31/2016', '12/23/2010',
#        '10/14/2014', '01-11-2012', '02-02-2010', '8/18/2013', '3/25/2013',
#        '11/26/2011', '9/17/2013', '06-08-2012', '6/30/2010', '2/23/2015',
#        '01-05-2012', '04-07-2014', '06-09-2013', '6/26/2013',
#        '11-07-2011', '10/30/2010', '10/13/2013', '10-11-2013',
#        '07-08-2012', '7/25/2016', '10/24/2010', '4/25/2015', '4/23/2013',
#        '8/14/2015', '5/26/2011', '5/20/2017', '07-05-2013', '11-06-2014',
#        '10/28/2014', '9/15/2011', '5/29/2012', '7/20/2013', '10/21/2012',
#        '9/18/2012', '11/15/2016', '01-04-2011', '3/18/2012', '2/17/2012',
#        '1/16/2011', '02-03-2014', '4/30/2012', '10/23/2016', '12-06-2016',
#        '07-07-2014', '6/13/2012', '11/26/2010', '02-08-2011', '7/26/2011',
#        '11-11-2011', '06-01-2016', '7/30/2015', '02-10-2012'],
#       dtype=object)

# %%
order_dates = ['5/28/2010', '8/22/2012', '05-02-2014', '6/20/2014', '02-01-2013',
       '02-04-2015', '4/23/2011', '7/17/2012', '7/14/2015', '4/18/2014',
       '6/24/2011', '08-02-2014', '1/13/2017', '02-08-2017', '2/19/2014',
       '4/23/2012', '11/19/2016', '04-01-2015', '12/30/2010', '7/31/2012',
       '5/14/2014', '7/31/2015', '6/30/2016', '09-08-2014', '05-07-2016',
       '5/22/2017', '10/13/2014', '05-07-2010', '7/18/2014', '5/26/2012',
       '9/17/2012', '12/29/2013', '10/27/2015', '1/16/2015', '2/25/2017',
       '05-08-2017', '11/22/2011', '1/14/2017', '04-01-2012', '2/16/2012',
       '03-11-2017', '02-06-2010', '06-07-2012', '10-06-2012',
       '11/14/2015', '3/29/2016', '12/31/2016', '12/23/2010',
       '10/14/2014', '01-11-2012', '02-02-2010', '8/18/2013', '3/25/2013',
       '11/26/2011', '9/17/2013', '06-08-2012', '6/30/2010', '2/23/2015',
       '01-05-2012', '04-07-2014', '06-09-2013', '6/26/2013',
       '11-07-2011', '10/30/2010', '10/13/2013', '10-11-2013',
       '07-08-2012', '7/25/2016', '10/24/2010', '4/25/2015', '4/23/2013',
       '8/14/2015', '5/26/2011', '5/20/2017', '07-05-2013', '11-06-2014',
       '10/28/2014', '9/15/2011', '5/29/2012', '7/20/2013', '10/21/2012',
       '9/18/2012', '11/15/2016', '01-04-2011', '3/18/2012', '2/17/2012',
       '1/16/2011', '02-03-2014', '4/30/2012', '10/23/2016', '12-06-2016',
       '07-07-2014', '6/13/2012', '11/26/2010', '02-08-2011', '7/26/2011',
       '11-11-2011', '06-01-2016', '7/30/2015', '02-10-2012']

# %%
sales_data['Order Date'] = pd.Categorical(sales_data['Order Date'],categories=order_dates,ordered=True)

# %%
pd.pivot_table(sales_data,values='Total Profit',index='Order Date',aggfunc='count').plot(kind='hist',color='aqua',stacked=False,legend=None)
mp.xticks(rotation=90)
mp.ylabel('Total Profit')
mp.locator_params(nbins=32)
mp.xlabel('Order Date')
# Out:
# Text(0.5, 0, 'Order Date')

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 669165933 to 665095412
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Date      100 non-null    category
#  1   Order Priority  100 non-null    object
#  2   Ship Date       100 non-null    object
#  3   Item Type       100 non-null    category
#  4   Region          100 non-null    object
#  5   Country         100 non-null    object
#  6   Sales Channel   100 non-null    object
#  7   Units Sold      100 non-null    int64
#  8   Unit Price      100 non-null    float64
#  9   Unit Cost       100 non-null    float64
#  10  Total Revenue   100 non-null    float64
#  11  Total Cost      100 non-null    float64
#  12  Total Profit    100 non-null    float64
# dtypes: category(2), float64(5), int64(1), object(5)
# memory usage: 14.8+ KB

# %%
sales_data.describe()
# Out:
#         Units Sold  Unit Price   Unit Cost  Total Revenue    Total Cost  \
# count   100.000000  100.000000  100.000000   1.000000e+02  1.000000e+02
# mean   5128.710000  276.761300  191.048000   1.373488e+06  9.318057e+05
# std    2794.484562  235.592241  188.208181   1.460029e+06  1.083938e+06
# min     124.000000    9.330000    6.920000   4.870260e+03  3.612240e+03
# 25%    2836.250000   81.730000   35.840000   2.687212e+05  1.688680e+05
# 50%    5382.500000  179.880000  107.275000   7.523144e+05  3.635664e+05
# 75%    7369.000000  437.200000  263.330000   2.212045e+06  1.613870e+06
# max    9925.000000  668.270000  524.960000   5.997055e+06  4.509794e+06
#
#        Total Profit
# count  1.000000e+02
# mean   4.416820e+05
# std    4.385379e+05
# min    1.258020e+03
# 25%    1.214436e+05
# 50%    2.907680e+05
# 75%    6.358288e+05
# max    1.719922e+06

# %%
sales_data
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
# ...               ...            ...         ...              ...
# 512878119   7/26/2011              M  09-03-2011          Clothes
# 810711038  11-11-2011              L  12/28/2011           Fruits
# 728815257  06-01-2016              C   6/29/2016       Vegetables
# 559427106   7/30/2015              M  08-08-2015    Personal Care
# 665095412  02-10-2012              L   2/15/2012        Household
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
# ...                                      ...                    ...
# 512878119                 Sub-Saharan Africa                   Mali
# 810711038                               Asia               Malaysia
# 728815257                 Sub-Saharan Africa           Sierra Leone
# 559427106                      North America                 Mexico
# 665095412                 Sub-Saharan Africa             Mozambique
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
# ...                 ...         ...         ...        ...            ...
# 512878119        Online         888      109.28      35.84     3039414.40
# 810711038       Offline        6267        9.33       6.92     3586605.09
# 728815257       Offline        1485      154.06      90.93     2798046.49
# 559427106       Offline        5767       81.73      56.67     3296425.02
# 665095412       Offline        5367      668.27     502.54     5997054.98
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50
# ...               ...           ...
# 512878119    31825.92      65214.72
# 810711038    43367.64      15103.47
# 728815257   135031.05      93748.05
# 559427106   326815.89     144521.02
# 665095412  2697132.18     889472.91
#
# [100 rows x 13 columns]

# %%
sales_data['Region'].unique()
# Out:
# array(['Australia and Oceania', 'Central America and the Caribbean',
#        'Europe', 'Sub-Saharan Africa', 'Asia',
#        'Middle East and North Africa', 'North America'], dtype=object)

# %%
regions = ['Australia and Oceania', 'Central America and the Caribbean',
       'Europe', 'Sub-Saharan Africa', 'Asia',
       'Middle East and North Africa', 'North America']

# %%
sales_data['Region'] = pd.Categorical(sales_data['Region'],categories = regions,ordered=True)

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
mp.scatter(sales_data['Units Sold'],sales_data['Total Cost'])
mp.xlabel('Units Sold')
mp.ylabel('Total Cost')
# Out:
# Text(0, 0.5, 'Total Cost')

# %% [markdown]
# ### More the number of units sold of a product, more will be the total cost associated with it.

# %%
sn.barplot(x='Region',y='Total Cost',data=sales_data)
mp.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Australia and Oceania'),
#   Text(1, 0, 'Central America and the Caribbean'),
#   Text(2, 0, 'Europe'),
#   Text(3, 0, 'Sub-Saharan Africa'),
#   Text(4, 0, 'Asia'),
#   Text(5, 0, 'Middle East and North Africa'),
#   Text(6, 0, 'North America')])

# %% [markdown]
# ### Cost of items is maximum in Asia and North America, and minimum in Sub-Saharan Africa.

# %%
sn.pairplot(sales_data)

# %%
sn.heatmap(sales_data.corr(),annot=True)
# Out:
# <ipython-input-69-a7f2a387fb36>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(sales_data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ### From the above heatmap, we can infer that Total Cost is strongly related to Unit Price,Unit Cost and Total Profit.
# ### Units Sold and {Unit Price and Unit Cost} are completely independent. Number of units sold are independent of price charged per unit of a product and same with cost of a unit which is independent of units sold.

# %% [markdown]
# ### Unit Cost, Unit Price and Total Cost are almost completely independent of Total Revenue.

# %%
mp.figure(figsize=(10,4))
sn.lineplot(x='Region',y='Total Cost',data=sales_data,ci=None)
mp.xticks(rotation=45)
# Out:
# <ipython-input-70-8ea0a5d66eef>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sn.lineplot(x='Region',y='Total Cost',data=sales_data,ci=None)
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Sub-Saharan Africa'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Middle East and North Africa'),
#   Text(3, 0, 'Asia'),
#   Text(4, 0, 'Central America and the Caribbean'),
#   Text(5, 0, 'Australia and Oceania'),
#   Text(6, 0, 'North America')])

# %% [markdown]
# #### Products have been much more expensive in Asia and North America in comparison to other continents.

# %%
sales_data.head()
# Out:
#            Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 292494523   1/27/2011              L  2/12/2011  Office Supplies
# 361825549  12/28/2015              C  1/23/2016        Beverages
# 141515767   1/13/2011              C   2/1/2011       Vegetables
# 500364005   9/11/2012              C  10/6/2012        Household
# 127481591  10/27/2015              C  12/5/2015        Beverages
#
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 292494523        Online        4484      651.21     524.96         167.94
# 361825549        Online        1075       47.45      31.79      308633.52
# 141515767       Offline        6515      154.06      90.93       51008.75
# 500364005        Online        7683      668.27     502.54       41369.22
# 127481591        Online        3491       47.45      31.79       17556.50
#
#            Total Cost  Total Profit
# Order ID
# 292494523  2353920.64     566105.00
# 361825549    34174.25      16834.50
# 141515767   592408.95     411291.95
# 500364005  3861014.82    1273303.59
# 127481591   110978.89      54669.06

# %%
sales_data['Country'].unique()
# Out:
# array(['Tuvalu', 'Grenada', 'Russia', 'Sao Tome and Principe', 'Rwanda',
#        'Solomon Islands', 'Angola', 'Burkina Faso',
#        'Republic of the Congo', 'Senegal', 'Kyrgyzstan', 'Cape Verde',
#        'Bangladesh', 'Honduras', 'Mongolia', 'Bulgaria', 'Sri Lanka',
#        'Cameroon', 'Turkmenistan', 'East Timor', 'Norway', 'Portugal',
#        'New Zealand', 'Moldova ', 'France', 'Kiribati', 'Mali',
#        'The Gambia', 'Switzerland', 'South Sudan', 'Australia', 'Myanmar',
#        'Djibouti', 'Costa Rica', 'Syria', 'Brunei', 'Niger', 'Azerbaijan',
#        'Slovakia', 'Comoros', 'Iceland', 'Macedonia', 'Mauritania',
#        'Albania', 'Lesotho', 'Saudi Arabia', 'Sierra Leone',
#        "Cote d'Ivoire", 'Fiji', 'Austria', 'United Kingdom', 'San Marino',
#        'Libya', 'Haiti', 'Gabon', 'Belize', 'Lithuania', 'Madagascar',
#        'Democratic Republic of the Congo', 'Pakistan', 'Mexico',
#        'Federated States of Micronesia', 'Laos', 'Monaco', 'Samoa ',
#        'Spain', 'Lebanon', 'Iran', 'Zambia', 'Kenya', 'Kuwait',
#        'Slovenia', 'Romania', 'Nicaragua', 'Malaysia', 'Mozambique'],
#       dtype=object)

# %%
countries = ['Tuvalu', 'Grenada', 'Russia', 'Sao Tome and Principe', 'Rwanda',
       'Solomon Islands', 'Angola', 'Burkina Faso',
       'Republic of the Congo', 'Senegal', 'Kyrgyzstan', 'Cape Verde',
       'Bangladesh', 'Honduras', 'Mongolia', 'Bulgaria', 'Sri Lanka',
       'Cameroon', 'Turkmenistan', 'East Timor', 'Norway', 'Portugal',
       'New Zealand', 'Moldova ', 'France', 'Kiribati', 'Mali',
       'The Gambia', 'Switzerland', 'South Sudan', 'Australia', 'Myanmar',
       'Djibouti', 'Costa Rica', 'Syria', 'Brunei', 'Niger', 'Azerbaijan',
       'Slovakia', 'Comoros', 'Iceland', 'Macedonia', 'Mauritania',
       'Albania', 'Lesotho', 'Saudi Arabia', 'Sierra Leone',
       "Cote d'Ivoire", 'Fiji', 'Austria', 'United Kingdom', 'San Marino',
       'Libya', 'Haiti', 'Gabon', 'Belize', 'Lithuania', 'Madagascar',
       'Democratic Republic of the Congo', 'Pakistan', 'Mexico',
       'Federated States of Micronesia', 'Laos', 'Monaco', 'Samoa ',
       'Spain', 'Lebanon', 'Iran', 'Zambia', 'Kenya', 'Kuwait',
       'Slovenia', 'Romania', 'Nicaragua', 'Malaysia', 'Mozambique']

# %%
sales_data['Country'] = pd.Categorical(sales_data['Country'],categories=countries,ordered=True)

# %%
mp.figure(figsize=(15,6))
sn.barplot(x='Country', y='Total Revenue', data=sales_data, ci=None)
mp.xticks(rotation=90)
mp.tick_params(axis='x', which='major', labelsize=10)

# %% [markdown]
# #### Mozambique is the country where maximum revenue has been generated followed by Kenya.

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
sn.lmplot(x='Unit Price',y='Total Cost',data=sales_data,col='Sales Channel',hue='Unit Cost',aspect=1.5,height=7)

# %%
sales_data.sort_values(by='Unit Price')
# Out:
#            Order Date Order Priority   Ship Date  Item Type  \
# Order ID
# 634285199   3/24/2011              L    5/7/2011     Fruits
# 515047919  12/14/2014              C   1/20/2015     Fruits
# 494722354   8/26/2016              H   10/7/2016     Fruits
# 517205703    6/8/2010              M   6/12/2010     Fruits
# 578969037   3/20/2017              H   3/25/2017     Fruits
# ...               ...            ...         ...        ...
# 433195912   3/21/2014              M   4/22/2014  Household
# 685374200   8/13/2015              M   8/28/2015  Household
# 846926009    1/6/2012              M    1/6/2012  Household
# 221285092  10/11/2010              M  10/18/2010  Household
# 254608857   11/4/2015              H  12/20/2015  Household
#
#                                       Region               Country  \
# Order ID
# 634285199  Central America and the Caribbean              Honduras
# 515047919       Middle East and North Africa  United Arab Emirates
# 494722354                 Sub-Saharan Africa              Cameroon
# 517205703                 Sub-Saharan Africa            Mauritius
# 578969037                               Asia           South Korea
# ...                                      ...                   ...
# 433195912       Middle East and North Africa              Tunisia
# 685374200                 Sub-Saharan Africa              Djibouti
# 846926009                             Europe                Sweden
# 221285092                             Europe          Vatican City
# 254608857                               Asia              Thailand
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 634285199       Offline        7941        9.33       6.92     1056886.60
# 515047919        Online        2980        9.33       6.92      394152.32
# 494722354        Online        8193        9.33       6.92       43151.25
# 517205703        Online        1516        9.33       6.92     2815421.51
# 578969037       Offline        8659        9.33       6.92     3184564.80
# ...                 ...         ...         ...        ...            ...
# 433195912       Offline        1152      668.27     502.54     1419046.66
# 685374200        Online        6311      668.27     502.54      252671.25
# 846926009       Offline        3082      668.27     502.54     2059608.14
# 221285092        Online        2031      668.27     502.54     1357256.37
# 254608857       Offline        3274      668.27     502.54     3190277.79
#
#            Total Cost  Total Profit
# Order ID
# 634285199    54951.72      19137.81
# 515047919    20621.60       7181.80
# 494722354    56695.56      19745.13
# 517205703    10490.72       3653.56
# 578969037    59920.28      20868.19
# ...               ...           ...
# 433195912   578926.08     190920.96
# 685374200  3171529.94    1045922.03
# 846926009  1548828.28     510779.86
# 221285092  1020658.74     336597.63
# 254608857  1645315.96     542600.02
#
# [10000 rows x 13 columns]

# %%
sales_data.plot.bar(x='Unit Price',y='Total Cost',legend=None,figsize=(15,10),rot=0)
mp.ylabel('Total Cost')
mp.xticks(rotation=90)
mp.locator_params(nbins=90)

# %% [markdown]
# ### The above bar plot suggests that higher the value of unit price of a product, more will be the total cost of it.

# %%
np.cov(sales_data['Unit Price'],sales_data['Total Cost'])
# Out:
# array([[5.55037038e+04, 2.01205393e+08],
#        [2.01205393e+08, 1.17492213e+12]])

# %%
np.corrcoef(sales_data['Unit Price'],sales_data['Total Cost'])
# Out:
# array([[1.        , 0.78790543],
#        [0.78790543, 1.        ]])

# %% [markdown]
# ### The high value of degree of correlation between 'Unit Price' and 'Total Cost' variables indicates that they are almost directly proportional to each other and highly dependent on each other.

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
pd.pivot_table(sales_data,index='Item Type',values='Total Profit',aggfunc=np.median).plot(kind='line',color='green',figsize=(15,5),legend=None)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
sales_data.groupby('Region')['Total Profit'].count().plot(kind='area',color=['purple','brown','blue','green'])
mp.xticks(rotation=90)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# #### Maximum profit has been generated in the Sub-Saharan African region while minimum profit has been generated in the North American region.

# %%
sales_data['Order Priority'].unique()
# Out:
# array(['H', 'C', 'L', 'M'], dtype=object)

# %%
order_priorities = ['H', 'C', 'L', 'M']

# %%
sales_data['Order Priority'] = pd.Categorical(sales_data['Order Priority'],categories=order_priorities,ordered=True)

# %%
sales_data.plot.bar(x='Order Priority',y='Total Revenue',legend=None,figsize=(16,8))
mp.xticks(rotation=90)
mp.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')

# %%
sales_data.groupby('Order Priority')['Total Revenue'].count().plot(kind='bar',color=['grey','blue','green','purple','brown'])
mp.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')

# %% [markdown]
# ### Maximum number of revenues has been generated by the products having order priority 'H' while minimum revenues has been generated by 'M' priority products.

# %%
sales_data.groupby('Order Priority')['Total Profit'].sum().plot(kind='bar',color=['brown','red','purple','aqua'])
mp.ylabel('Total Profit')
mp.title('Distribution of profit on the basis of order priority')
# Out:
# Text(0.5, 1.0, 'Distribution of profit on the basis of order priority')

# %% [markdown]
# ### Maximum profit has been generated by products having order priority 'H' while minimum profit has been obtained in case of 'C' priority product orders.

# %%
pip install joypy
# Out:
# Collecting joypy
#   Downloading joypy-0.2.6-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from joypy) (1.23.5)
# Requirement already satisfied: scipy>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from joypy) (1.11.4)
# Requirement already satisfied: pandas>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from joypy) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from joypy) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->joypy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.20.0->joypy) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joypy) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.20.0->joypy) (1.16.0)
# Installing collected packages: joypy
# Successfully installed joypy-0.2.6

# %%
import joypy

# %%
joypy.joyplot(sales_data,column=['Total Revenue','Total Cost','Total Profit'],by='Item Type',figsize=(9,6),xlabelsize=13,ylim='own',ylabelsize=13,grid='both',yrot=10,fill=True,legend=True,overlap=2)
# Out:
# (<Figure size 900x600 with 13 Axes>,
#  [<Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >,
#   <Axes: >])

# %%
sales_data.head(10)
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
# 547995746  02-04-2015              C   2/21/2015        Baby Food
# 135425221   4/23/2011              M   4/27/2011        Household
# 871543967   7/17/2012              H   7/27/2012       Vegetables
# 770463311   7/14/2015              M   8/25/2015    Personal Care
# 616607081   4/18/2014              H   5/30/2014           Cereal
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
# 547995746              Australia and Oceania        Solomon Islands
# 135425221                 Sub-Saharan Africa                 Angola
# 871543967                 Sub-Saharan Africa           Burkina Faso
# 770463311                 Sub-Saharan Africa  Republic of the Congo
# 616607081                 Sub-Saharan Africa                Senegal
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
# 547995746        Online        2974      255.28     159.42        6279.09
# 135425221       Offline        4187      668.27     502.54      228779.10
# 871543967        Online        8082      154.06      90.93      524870.06
# 770463311       Offline        6070       81.73      56.67      496101.10
# 616607081        Online        6593      205.70     117.11      140287.40
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50
# 547995746   474115.08     285087.64
# 135425221  2104134.98     693911.51
# 871543967   734896.26     510216.66
# 770463311   343986.90     152114.20
# 616607081   772106.23     584073.87

# %%
mp.figure(figsize=(12,5))
sales_data.groupby('Ship Date')['Total Profit'].sum().plot(kind='line',color='blue',sort_columns=True)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ### Maximum profit has been achieved during the year 2014.

# %%
np.max(sales_data.loc[:,'Total Profit'].iloc[:])
# Out:
# 1719922.04

# %%
np.set_printoptions = True

# %%
sales_data.head(8)
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
# 547995746  02-04-2015              C   2/21/2015        Baby Food
# 135425221   4/23/2011              M   4/27/2011        Household
# 871543967   7/17/2012              H   7/27/2012       Vegetables
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
# 547995746              Australia and Oceania        Solomon Islands
# 135425221                 Sub-Saharan Africa                 Angola
# 871543967                 Sub-Saharan Africa           Burkina Faso
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
# 547995746        Online        2974      255.28     159.42        6279.09
# 135425221       Offline        4187      668.27     502.54      228779.10
# 871543967        Online        8082      154.06      90.93      524870.06
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50
# 547995746   474115.08     285087.64
# 135425221  2104134.98     693911.51
# 871543967   734896.26     510216.66

# %%
pd.DataFrame(sales_data.value_counts())
# Out:
#                                                                                                                                                                                                   0
# Order Date Order Priority Ship Date  Item Type Region                       Country                          Sales Channel Units Sold Unit Price Unit Cost Total Revenue Total Cost Total Profit
# 5/28/2010  H              6/27/2010  Baby Food Australia and Oceania        Tuvalu                           Offline       9925       255.28     159.42    4870.26       1582243.50 951410.50     1
# 10/30/2010 H              11/17/2010 Clothes   Middle East and North Africa Libya                            Offline       6116       109.28     35.84     835759.10     219197.44  449159.04     1
# 5/20/2017  H              6/17/2017  Cereal    Sub-Saharan Africa           Djibouti                         Online        8656       205.70     117.11    1780539.20    1013704.16 766835.04     1
# 5/26/2011  C              7/15/2011  Beverages Sub-Saharan Africa           Democratic Republic of the Congo Online        5741       47.45      31.79     1158502.59    182506.39  89904.06      1
# 8/14/2015  L              9/30/2015  Fruits    Middle East and North Africa Libya                            Online        673        9.33       6.92      1117953.66    4657.16    1621.93       1
# ...                                                                                                                                                                                              ..
# 9/17/2012  M              10/20/2012 Cosmetics Europe                       Switzerland                      Offline       8661       437.20     263.33    247956.32     2280701.13 1505888.07    1
# 5/26/2012  L              06-09-2012 Household Sub-Saharan Africa           The Gambia                       Offline       2370       668.27     502.54    89623.98      1191019.80 392780.10     1
# 7/18/2014  C              7/30/2014  Beverages Europe                       Norway                           Offline       5124       47.45      31.79     243133.80     162891.96  80241.84      1
# 05-07-2010 L              05-10-2010 Fruits    Sub-Saharan Africa           Mali                             Online        5822       9.33       6.92      54319.26      40288.24   14031.02      1
# 02-10-2012 L              2/15/2012  Household Sub-Saharan Africa           Mozambique                       Offline       5367       668.27     502.54    5997054.98    2697132.18 889472.91     1
#
# [100 rows x 1 columns]

# %%
sn.jointplot(x='Item Type',y='Unit Cost',data=sales_data,kind='scatter',color="g",height=15,ratio=5,dropna=True,space=2)
mp.locator_params(nbins=10)
mp.xticks(rotation=90)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45.]), [])

# %% [markdown]
# ### Office Supplies have the maximum unit cost while Fruits have minimum unit cost.

# %%
np.max(sales_data['Unit Cost'])
# Out:
# 524.96

# %%
temp = sales_data.copy()
temp['Unit Cost'] = temp['Unit Cost'].sort_values()

# %%
temp.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
temp.sort_values(by='Unit Cost',inplace=True)

# %%
temp.tail(1)
# Out:
#            Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 837559306  01-11-2012              C  1/13/2012  Office Supplies
#
#                        Region     Country Sales Channel  Units Sold  \
# Order ID
# 837559306  Sub-Saharan Africa  Mauritania       Offline        1266
#
#            Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# Order ID
# 837559306      651.21     524.96       745426.0   664599.36      159832.5

# %%
temp.head(1)
# Out:
#           Order Date Order Priority   Ship Date Item Type              Region  \
# Order ID
# 508980977  9/17/2013              H  10/24/2013    Fruits  Sub-Saharan Africa
#
#                          Country Sales Channel  Units Sold  Unit Price  \
# Order ID
# 508980977  Sao Tome and Principe       Offline        7637        9.33
#
#            Unit Cost  Total Revenue  Total Cost  Total Profit
# Order ID
# 508980977       6.92     2251232.97    52848.04      18405.17

# %%
sales_data.head()
# Out:
#            Order Date Order Priority   Ship Date        Item Type  \
# Order ID
# 669165933   5/28/2010              H   6/27/2010        Baby Food
# 963881480   8/22/2012              C   9/15/2012           Cereal
# 341417157  05-02-2014              L  05-08-2014  Office Supplies
# 514321792   6/20/2014              C  07-05-2014           Fruits
# 115456712  02-01-2013              L  02-06-2013  Office Supplies
#
#                                       Region                Country  \
# Order ID
# 669165933              Australia and Oceania                 Tuvalu
# 963881480  Central America and the Caribbean                Grenada
# 341417157                             Europe                 Russia
# 514321792                 Sub-Saharan Africa  Sao Tome and Principe
# 115456712                 Sub-Saharan Africa                 Rwanda
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 669165933       Offline        9925      255.28     159.42        4870.26
# 963881480        Online        2804      205.70     117.11      445033.55
# 341417157       Offline        1779      651.21     524.96      272410.45
# 514321792        Online        8102        9.33       6.92       75591.66
# 115456712       Offline        5062      651.21     524.96      471336.91
#
#            Total Cost  Total Profit
# Order ID
# 669165933  1582243.50     951410.50
# 963881480   328376.44     248406.36
# 341417157   933903.84     224598.75
# 514321792    56065.84      19525.82
# 115456712  2657347.52     639077.50

# %%
sn.jointplot(x='Total Profit',data=sales_data,height=8,ratio=5,kind='kde',space=1.5)

# %%
sales_data['Item Type'].value_counts()
# Out:
# Clothes            13
# Cosmetics          13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Baby Food           7
# Cereal              7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: Item Type, dtype: int64

# %%
sales_data['Item Type'].dropna(inplace=True)

# %%
labels = sales_data['Item Type'].value_counts().index

# %%
sizes = sales_data['Item Type'].value_counts().values
colors = ['grey','blue','red','lime','purple','brown']

# %%
mp.figure(figsize=(7,7))
mp.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%')
mp.title('Distribution of Item Types',fontsize=15,color='blue')
# Out:
# Text(0.5, 1.0, 'Distribution of Item Types')

# %% [markdown]
# ### Clothes and cosmetics are the most purchased items while meat and snacks are the least purchased ones.

# %% [markdown]
# # LM Plot

# %%
sales_data.head()
# Out:
#            Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 292494523   1/27/2011              L  2/12/2011  Office Supplies
# 361825549  12/28/2015              C  1/23/2016        Beverages
# 141515767   1/13/2011              C   2/1/2011       Vegetables
# 500364005   9/11/2012              C  10/6/2012        Household
# 127481591  10/27/2015              C  12/5/2015        Beverages
#
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 292494523        Online        4484      651.21     524.96         167.94
# 361825549        Online        1075       47.45      31.79      308633.52
# 141515767       Offline        6515      154.06      90.93       51008.75
# 500364005        Online        7683      668.27     502.54       41369.22
# 127481591        Online        3491       47.45      31.79       17556.50
#
#            Total Cost  Total Profit
# Order ID
# 292494523  2353920.64     566105.00
# 361825549    34174.25      16834.50
# 141515767   592408.95     411291.95
# 500364005  3861014.82    1273303.59
# 127481591   110978.89      54669.06

# %%
sales_data['Country'].nunique()
# Out:
# 185

# %%
countries_data = pd.DataFrame(sales_data['Country'].unique())
countries_data
# Out:
#                                     0
# 0                                Chad
# 1                              Latvia
# 2                            Pakistan
# 3    Democratic Republic of the Congo
# 4                      Czech Republic
# ..                                ...
# 180                            Jordan
# 181                     Guinea-Bissau
# 182                           Bahrain
# 183                     Cote d'Ivoire
# 184                          Malaysia
#
# [185 rows x 1 columns]

# %%
countries_data.value_counts()
# Out:
# Afghanistan    1
# Poland         1
# Nigeria        1
# North Korea    1
# Norway         1
#               ..
# Haiti          1
# Honduras       1
# Hungary        1
# Iceland        1
# Zimbabwe       1
# Length: 185, dtype: int64

# %%
countries = sales_data['Country'].values.tolist()

# %%
countries
# Out:
# ['Chad',
#  'Latvia',
#  'Pakistan',
#  'Democratic Republic of the Congo',
#  'Czech Republic',
#  'South Africa',
#  'Laos',
#  'China',
#  'Eritrea',
#  'Haiti',
#  'Zambia',
#  'Bosnia and Herzegovina',
#  'Germany',
#  'India',
#  'Algeria',
#  'Palau',
#  'Cuba',
#  'Vatican City',
#  'Lebanon',
#  'Lithuania',
#  'Mauritius ',
#  'Ukraine',
#  'Russia',
#  'Japan',
#  'Russia',
#  'Liechtenstein',
#  'Greece',
#  'Albania',
#  'Federated States of Micronesia',
#  'Dominica',
#  'Andorra',
#  'Switzerland',
#  'Trinidad and Tobago',
#  'San Marino',
#  'Nicaragua',
#  'Azerbaijan',
#  'Bangladesh',
#  'Serbia',
#  'Mauritius ',
#  'Jamaica',
#  'Italy',
#  'Bhutan',
#  'Turkey',
#  'Bulgaria',
#  'Pakistan',
#  'Poland',
#  'France',
#  'Jamaica',
#  'Australia',
#  'Somalia',
#  'Slovenia',
#  'Samoa ',
#  'South Africa',
#  'Ghana',
#  'Sri Lanka',
#  'Guinea',
#  'Spain',
#  'Moldova ',
#  'Dominican Republic',
#  'Luxembourg',
#  'Kuwait',
#  'Saint Lucia',
#  'Georgia',
#  'Bosnia and Herzegovina',
#  'Iceland',
#  'Mauritius ',
#  'Malawi',
#  'Seychelles ',
#  'Montenegro',
#  'Germany',
#  'Estonia',
#  'Serbia',
#  'Madagascar',
#  'Benin',
#  'Hungary',
#  'Cuba',
#  'Senegal',
#  'Algeria',
#  'Bosnia and Herzegovina',
#  'Antigua and Barbuda ',
#  'Cambodia',
#  'Oman',
#  'United States of America',
#  'Mauritania',
#  'Central African Republic',
#  'Albania',
#  'Switzerland',
#  'Ghana',
#  'Austria',
#  'Democratic Republic of the Congo',
#  'Dominican Republic',
#  'Mauritius ',
#  'Libya',
#  'Samoa ',
#  'Kuwait',
#  'Hungary',
#  'Senegal',
#  'Moldova ',
#  'Eritrea',
#  'Niger',
#  'Saint Lucia',
#  'Sweden',
#  'Jamaica',
#  'Haiti',
#  'Samoa ',
#  'Dominican Republic',
#  'Tunisia ',
#  'Taiwan',
#  'Tunisia ',
#  'Sri Lanka',
#  'Indonesia',
#  'Ethiopia',
#  'Swaziland',
#  'Portugal',
#  'Hungary',
#  'Zimbabwe',
#  'Armenia',
#  'North Korea',
#  'Burkina Faso',
#  'India',
#  'Sao Tome and Principe',
#  'Armenia',
#  'Georgia',
#  'Serbia',
#  'Tuvalu',
#  'Barbados',
#  'Mali',
#  'Central African Republic',
#  'Sri Lanka',
#  'Bosnia and Herzegovina',
#  'Netherlands',
#  'Laos',
#  'Honduras',
#  'Zambia',
#  'Botswana',
#  'Bhutan',
#  'Zimbabwe',
#  'Lesotho',
#  'Togo',
#  'Australia',
#  'Luxembourg',
#  'Estonia',
#  'United Kingdom',
#  'Morocco',
#  'United Kingdom',
#  'Papua New Guinea',
#  'New Zealand',
#  'Austria',
#  'Saint Kitts and Nevis ',
#  'Myanmar',
#  'Guatemala',
#  'Antigua and Barbuda ',
#  'Iran',
#  'Singapore',
#  'Sudan',
#  'Macedonia',
#  'Canada',
#  'Malta',
#  'Iraq',
#  'Austria',
#  'Thailand',
#  'Netherlands',
#  'Zimbabwe',
#  'Belize',
#  'Georgia',
#  'Dominica',
#  'Slovakia',
#  'Benin',
#  'Jamaica',
#  'Syria',
#  'Bulgaria',
#  'Tonga',
#  'Finland',
#  'Namibia',
#  'Kenya',
#  'Kiribati',
#  'Australia',
#  'Eritrea',
#  'Bulgaria',
#  'Australia',
#  'The Gambia',
#  'Latvia',
#  'Bulgaria',
#  'France',
#  'United Arab Emirates',
#  'Kuwait',
#  'Iran',
#  'Jamaica',
#  'Rwanda',
#  'United States of America',
#  'Cyprus',
#  'Afghanistan',
#  'Uganda',
#  'Senegal',
#  'Afghanistan',
#  'Estonia',
#  'Senegal',
#  'Vatican City',
#  'Laos',
#  'Dominican Republic',
#  'Nepal',
#  'Palau',
#  'Serbia',
#  'Cyprus',
#  'Indonesia',
#  'Dominica',
#  'Malawi',
#  'East Timor',
#  'Mongolia',
#  'Kenya',
#  'Moldova ',
#  'Mozambique',
#  'Saint Kitts and Nevis ',
#  'Papua New Guinea',
#  'Guinea',
#  'Lithuania',
#  'Tajikistan',
#  'Antigua and Barbuda ',
#  'Saudi Arabia',
#  'Myanmar',
#  'Australia',
#  'Kiribati',
#  'Pakistan',
#  'Albania',
#  'Norway',
#  'Vatican City',
#  'Algeria',
#  'Hungary',
#  'Tajikistan',
#  'Djibouti',
#  'Macedonia',
#  'Lesotho',
#  'Denmark',
#  'Nauru',
#  'Moldova ',
#  'Australia',
#  'Slovenia',
#  'Guatemala',
#  'Dominican Republic',
#  'Israel',
#  'Brunei',
#  'Myanmar',
#  'Croatia',
#  'Tonga',
#  'Belarus',
#  'Mali',
#  'Bangladesh',
#  'Djibouti',
#  'Eritrea',
#  'Iran',
#  'Kyrgyzstan',
#  'Mauritius ',
#  'Ghana',
#  'Dominican Republic',
#  'Togo',
#  'Angola',
#  'Ghana',
#  'Romania',
#  'Zimbabwe',
#  'Benin',
#  'Algeria',
#  'Lebanon',
#  'Vatican City',
#  'Somalia',
#  'Estonia',
#  'Libya',
#  'Uzbekistan',
#  'Lesotho',
#  'Democratic Republic of the Congo',
#  'Tanzania',
#  'Vietnam',
#  'Comoros',
#  'Comoros',
#  'Trinidad and Tobago',
#  'Palau',
#  'Macedonia',
#  'Comoros',
#  'Zambia',
#  'Vanuatu',
#  'Cyprus',
#  'Thailand',
#  'Kyrgyzstan',
#  'Saint Vincent and the Grenadines',
#  'Mauritius ',
#  'Hungary',
#  'Switzerland',
#  'Denmark',
#  'Cyprus',
#  'Rwanda',
#  'Benin',
#  'Norway',
#  'Saudi Arabia',
#  'Nauru',
#  'Kiribati',
#  'Lithuania',
#  'Palau',
#  'Sri Lanka',
#  'Djibouti',
#  'Guatemala',
#  'Zimbabwe',
#  'Comoros',
#  'Netherlands',
#  'Portugal',
#  'Spain',
#  'Egypt',
#  'Slovenia',
#  'Ireland',
#  'Taiwan',
#  'Swaziland',
#  'Armenia',
#  'The Gambia',
#  'Iran',
#  'Andorra',
#  'Morocco',
#  'Bhutan',
#  'Mongolia',
#  'Eritrea',
#  'Central African Republic',
#  'Greenland',
#  'Somalia',
#  'Cameroon',
#  'Uzbekistan',
#  'Ethiopia',
#  'Kyrgyzstan',
#  'United Kingdom',
#  'Marshall Islands',
#  'North Korea',
#  'Nauru',
#  'Saint Lucia',
#  'Ukraine',
#  'Sao Tome and Principe',
#  'Bulgaria',
#  'Romania',
#  'Yemen',
#  'United States of America',
#  'Antigua and Barbuda ',
#  'Latvia',
#  'El Salvador',
#  'The Bahamas',
#  'Maldives',
#  'Nigeria',
#  'Zimbabwe',
#  'Armenia',
#  'Belarus',
#  'Kuwait',
#  'Panama',
#  'Turkmenistan',
#  'Guatemala',
#  'Sudan',
#  'Afghanistan',
#  'Sweden',
#  'Moldova ',
#  'Belgium',
#  'South Africa',
#  'Mauritania',
#  'Azerbaijan',
#  'Sao Tome and Principe',
#  'Libya',
#  'Portugal',
#  'Lebanon',
#  'Marshall Islands',
#  'Barbados',
#  'Sao Tome and Principe',
#  'Samoa ',
#  'Tonga',
#  'France',
#  'Liechtenstein',
#  'South Africa',
#  'Kosovo',
#  'Palau',
#  'Sweden',
#  'Bosnia and Herzegovina',
#  'Antigua and Barbuda ',
#  'Mauritius ',
#  'Costa Rica',
#  'Burundi',
#  'Sudan',
#  'Croatia',
#  'Cambodia',
#  'Liechtenstein',
#  'Lesotho',
#  'Sierra Leone',
#  'Somalia',
#  'Sudan',
#  'Botswana',
#  'South Africa',
#  'Saint Kitts and Nevis ',
#  'United Kingdom',
#  'Marshall Islands',
#  'Eritrea',
#  'Panama',
#  'Democratic Republic of the Congo',
#  'Brunei',
#  'Sudan',
#  'Jamaica',
#  'Togo',
#  'Andorra',
#  'Central African Republic',
#  'Cambodia',
#  'Poland',
#  'Afghanistan',
#  'El Salvador',
#  'Oman',
#  'Madagascar',
#  'India',
#  'Tonga',
#  'Panama',
#  'Denmark',
#  'Denmark',
#  'Yemen',
#  'Botswana',
#  'Portugal',
#  'Poland',
#  'Sao Tome and Principe',
#  'Equatorial Guinea',
#  'Grenada',
#  'Mauritania',
#  'Uzbekistan',
#  'Saudi Arabia',
#  'Afghanistan',
#  'Mali',
#  'Mexico',
#  'Costa Rica',
#  'Switzerland',
#  'Nigeria',
#  'Romania',
#  'Azerbaijan',
#  'Nepal',
#  'Czech Republic',
#  'Croatia',
#  'Latvia',
#  'Bulgaria',
#  'Botswana',
#  'Spain',
#  'Cape Verde',
#  'The Bahamas',
#  'Albania',
#  'Macedonia',
#  'Poland',
#  'Tunisia ',
#  'United States of America',
#  'Serbia',
#  'Myanmar',
#  'Liberia',
#  'Tanzania',
#  'Philippines',
#  'Bangladesh',
#  'Dominica',
#  'Democratic Republic of the Congo',
#  'Botswana',
#  'El Salvador',
#  'Japan',
#  'Monaco',
#  'Guatemala',
#  'Armenia',
#  'The Bahamas',
#  'Montenegro',
#  'Croatia',
#  'Portugal',
#  'Antigua and Barbuda ',
#  'Afghanistan',
#  'Kuwait',
#  'United States of America',
#  'Malta',
#  'New Zealand',
#  'Angola',
#  'Kiribati',
#  'Dominica',
#  'Armenia',
#  'Taiwan',
#  'Kazakhstan',
#  'Monaco',
#  'Vatican City',
#  'Palau',
#  'Albania',
#  'Ireland',
#  'Nepal',
#  'Haiti',
#  'India',
#  'Niger',
#  'Kosovo',
#  'Romania',
#  'Democratic Republic of the Congo',
#  'Kuwait',
#  'Mozambique',
#  'Kiribati',
#  'Gabon',
#  'South Africa',
#  'Malawi',
#  'Moldova ',
#  'Canada',
#  'Andorra',
#  'Djibouti',
#  'Finland',
#  'Poland',
#  'Mali',
#  'Brunei',
#  'Nepal',
#  'Federated States of Micronesia',
#  'South Africa',
#  'Kyrgyzstan',
#  'Maldives',
#  'Liechtenstein',
#  'Sudan',
#  'Albania',
#  'Comoros',
#  'Pakistan',
#  'Somalia',
#  'Kyrgyzstan',
#  'Kosovo',
#  'Namibia',
#  'France',
#  'Namibia',
#  'Canada',
#  'Haiti',
#  'Honduras',
#  'Tonga',
#  'Greenland',
#  'Tuvalu',
#  'Poland',
#  'Fiji',
#  'Mali',
#  'Greece',
#  'Yemen',
#  'Mongolia',
#  'The Gambia',
#  'Uzbekistan',
#  'Poland',
#  'Niger',
#  'Lesotho',
#  'Democratic Republic of the Congo',
#  'Moldova ',
#  'Grenada',
#  'Bulgaria',
#  'United Kingdom',
#  'El Salvador',
#  'Lesotho',
#  'Democratic Republic of the Congo',
#  'Marshall Islands',
#  'Germany',
#  'Liberia',
#  'Montenegro',
#  'Kosovo',
#  'Turkmenistan',
#  'India',
#  'Seychelles ',
#  'Albania',
#  'Bulgaria',
#  'Zambia',
#  'Latvia',
#  'Tuvalu',
#  'Bosnia and Herzegovina',
#  'Namibia',
#  'Norway',
#  'New Zealand',
#  'United Kingdom',
#  'Kuwait',
#  'Monaco',
#  'Cuba',
#  'Hungary',
#  'Macedonia',
#  'Ethiopia',
#  'United Arab Emirates',
#  'Tunisia ',
#  'Uganda',
#  'Malawi',
#  'Lithuania',
#  'Costa Rica',
#  'Kyrgyzstan',
#  'Bangladesh',
#  'Malta',
#  'Ethiopia',
#  'Austria',
#  'Ethiopia',
#  'Republic of the Congo',
#  'Iran',
#  'Bangladesh',
#  'Poland',
#  'Cape Verde',
#  'United Arab Emirates',
#  'El Salvador',
#  'Vatican City',
#  'The Gambia',
#  'Macedonia',
#  'Slovakia',
#  'Greece',
#  'Czech Republic',
#  'Kazakhstan',
#  'Maldives',
#  'Ireland',
#  'Liberia',
#  'United States of America',
#  'Guinea',
#  'Samoa ',
#  'Belize',
#  'Estonia',
#  'Solomon Islands',
#  'Barbados',
#  'South Korea',
#  'Mozambique',
#  'Singapore',
#  'Mexico',
#  'Botswana',
#  'Liechtenstein',
#  'Antigua and Barbuda ',
#  'Czech Republic',
#  'Mali',
#  'Slovakia',
#  'Equatorial Guinea',
#  'Croatia',
#  'Sudan',
#  'Serbia',
#  'North Korea',
#  'Zimbabwe',
#  'Belarus',
#  'Madagascar',
#  'Zimbabwe',
#  'Mexico',
#  'Poland',
#  'Namibia',
#  'Democratic Republic of the Congo',
#  'Dominican Republic',
#  'Guinea',
#  'Tuvalu',
#  'Swaziland',
#  'Romania',
#  'Saint Kitts and Nevis ',
#  'Cape Verde',
#  'Mauritius ',
#  'Dominican Republic',
#  'Russia',
#  'Denmark',
#  'Zimbabwe',
#  'Georgia',
#  'Burundi',
#  'Cyprus',
#  'Dominica',
#  'Egypt',
#  'Benin',
#  'Laos',
#  'Saudi Arabia',
#  'Montenegro',
#  'Niger',
#  'Papua New Guinea',
#  'Albania',
#  'Costa Rica',
#  'El Salvador',
#  'Montenegro',
#  'Singapore',
#  'Solomon Islands',
#  'Georgia',
#  'Sudan',
#  'Uzbekistan',
#  'Kyrgyzstan',
#  'Switzerland',
#  'Chad',
#  'Guinea',
#  'Qatar',
#  'San Marino',
#  'Bulgaria',
#  'Macedonia',
#  'South Sudan',
#  'Trinidad and Tobago',
#  'Sri Lanka',
#  'Slovakia',
#  'Moldova ',
#  'Portugal',
#  'Switzerland',
#  'Ireland',
#  'Andorra',
#  'Belarus',
#  'Zambia',
#  'Spain',
#  'Namibia',
#  'The Bahamas',
#  'Democratic Republic of the Congo',
#  'United Arab Emirates',
#  'Spain',
#  'Angola',
#  'France',
#  'Kyrgyzstan',
#  'Cameroon',
#  'Brunei',
#  'Lebanon',
#  'Croatia',
#  'Malawi',
#  'Cambodia',
#  'Burkina Faso',
#  'Macedonia',
#  'Tunisia ',
#  'Maldives',
#  'Kuwait',
#  'Liberia',
#  'Montenegro',
#  'Guatemala',
#  'Algeria',
#  'Namibia',
#  'Guinea',
#  'Bhutan',
#  'New Zealand',
#  'Kiribati',
#  'Saint Vincent and the Grenadines',
#  'Burundi',
#  'Cambodia',
#  'Canada',
#  'Slovakia',
#  'Japan',
#  'Equatorial Guinea',
#  'Brunei',
#  'Cameroon',
#  'Slovenia',
#  'Vatican City',
#  'Lesotho',
#  'Angola',
#  'Montenegro',
#  'Lesotho',
#  'Turkey',
#  'Mauritania',
#  'Austria',
#  'Australia',
#  'Niger',
#  'Mexico',
#  'Netherlands',
#  'France',
#  'East Timor',
#  'United Arab Emirates',
#  'Cyprus',
#  'Portugal',
#  'Fiji',
#  'Iceland',
#  'Croatia',
#  'Botswana',
#  'Yemen',
#  'Austria',
#  'Niger',
#  'Kosovo',
#  'Czech Republic',
#  'Luxembourg',
#  'Belarus',
#  'Cambodia',
#  'Canada',
#  'Afghanistan',
#  'Myanmar',
#  'Palau',
#  'Albania',
#  'Togo',
#  'Nicaragua',
#  'Panama',
#  'Palau',
#  'Mongolia',
#  'Czech Republic',
#  'Moldova ',
#  'Brunei',
#  'Philippines',
#  'Cuba',
#  'The Gambia',
#  'Mozambique',
#  'France',
#  'Malawi',
#  'Indonesia',
#  'Malawi',
#  'Syria',
#  'Kosovo',
#  'Trinidad and Tobago',
#  'Germany',
#  'Jordan',
#  'The Gambia',
#  'Indonesia',
#  'Tanzania',
#  'El Salvador',
#  'Bulgaria',
#  'Belize',
#  'Mauritania',
#  'Sierra Leone',
#  'Norway',
#  'Botswana',
#  'Vatican City',
#  'Lithuania',
#  'Dominican Republic',
#  'Ethiopia',
#  'Montenegro',
#  'Honduras',
#  'Turkmenistan',
#  'Lebanon',
#  'New Zealand',
#  'Zimbabwe',
#  'San Marino',
#  'Montenegro',
#  'Slovenia',
#  'Chad',
#  'Kazakhstan',
#  'South Africa',
#  'Montenegro',
#  'Ireland',
#  'Qatar',
#  'Uganda',
#  'Morocco',
#  'Greece',
#  'Netherlands',
#  'Kiribati',
#  'Oman',
#  'North Korea',
#  'Nepal',
#  'Ireland',
#  'Seychelles ',
#  'Senegal',
#  'Cuba',
#  'Saint Lucia',
#  'United States of America',
#  'Iran',
#  'Croatia',
#  'Thailand',
#  'Burundi',
#  'Malta',
#  'Central African Republic',
#  'Somalia',
#  'Botswana',
#  'Bangladesh',
#  'Vietnam',
#  'Kosovo',
#  'Australia',
#  'Cyprus',
#  'South Korea',
#  'Solomon Islands',
#  'Rwanda',
#  'Lesotho',
#  'Nigeria',
#  'Macedonia',
#  'Nigeria',
#  'Malawi',
#  'Tanzania',
#  'Sri Lanka',
#  'Croatia',
#  'Guinea',
#  'Saint Kitts and Nevis ',
#  'Portugal',
#  'Burkina Faso',
#  'Singapore',
#  'Russia',
#  'Sudan',
#  'Denmark',
#  'Morocco',
#  'Malawi',
#  'Guinea-Bissau',
#  'Cameroon',
#  'Slovenia',
#  'Indonesia',
#  'Mexico',
#  'Afghanistan',
#  'Germany',
#  'Costa Rica',
#  'Grenada',
#  'Tajikistan',
#  'Libya',
#  'Niger',
#  'France',
#  'Brunei',
#  'Poland',
#  'Libya',
#  'Kuwait',
#  'Qatar',
#  'Sweden',
#  'Taiwan',
#  'United States of America',
#  'Iran',
#  'The Gambia',
#  'Nauru',
#  'Mali',
#  'Turkey',
#  'Jamaica',
#  'Turkmenistan',
#  'Italy',
#  'Sudan',
#  'Ukraine',
#  'South Korea',
#  'Burundi',
#  'Poland',
#  'Namibia',
#  'Uzbekistan',
#  'Taiwan',
#  'Kosovo',
#  'Samoa ',
#  'Guinea',
#  'Maldives',
#  'Mongolia',
#  'Germany',
#  'Iceland',
#  'Tonga',
#  'Marshall Islands',
#  'Kosovo',
#  'France',
#  'Somalia',
#  'Ireland',
#  'Romania',
#  'Philippines',
#  'Tunisia ',
#  'Madagascar',
#  'Bhutan',
#  'Indonesia',
#  'Macedonia',
#  'Grenada',
#  'Lithuania',
#  'The Bahamas',
#  'Algeria',
#  'Kuwait',
#  'Maldives',
#  'Maldives',
#  'Seychelles ',
#  'Vanuatu',
#  'Moldova ',
#  'Bangladesh',
#  'Federated States of Micronesia',
#  'Latvia',
#  'Senegal',
#  'Djibouti',
#  'Mozambique',
#  'Mauritania',
#  'Guinea-Bissau',
#  'Burundi',
#  'Swaziland',
#  'Saint Lucia',
#  'Dominica',
#  'Tunisia ',
#  'Antigua and Barbuda ',
#  'Belgium',
#  'Chad',
#  'Rwanda',
#  'Oman',
#  'Jordan',
#  'United Kingdom',
#  'South Sudan',
#  'Belarus',
#  'Republic of the Congo',
#  'Poland',
#  'Ethiopia',
#  'Jordan',
#  'Armenia',
#  'Zimbabwe',
#  'Sierra Leone',
#  'Bosnia and Herzegovina',
#  'Belgium',
#  'Belarus',
#  'Panama',
#  'North Korea',
#  'Egypt',
#  'Bhutan',
#  'Portugal',
#  'Niger',
#  'Bosnia and Herzegovina',
#  'Poland',
#  'Gabon',
#  'South Korea',
#  'Sri Lanka',
#  'South Korea',
#  'Australia',
#  'Thailand',
#  'Tonga',
#  'Lebanon',
#  'Greece',
#  'Norway',
#  'Finland',
#  'Bosnia and Herzegovina',
#  'Slovakia',
#  'Montenegro',
#  'Dominican Republic',
#  'Guinea-Bissau',
#  'Chad',
#  'Slovakia',
#  'Thailand',
#  'Brunei',
#  'Macedonia',
#  'Brunei',
#  'Greece',
#  'Malta',
#  'India',
#  'Macedonia',
#  'Comoros',
#  'Malta',
#  'Nauru',
#  'Sri Lanka',
#  'Barbados',
#  'Lithuania',
#  'El Salvador',
#  'Slovakia',
#  'Estonia',
#  'Lesotho',
#  'Georgia',
#  'Papua New Guinea',
#  'Montenegro',
#  'Palau',
#  'Saint Kitts and Nevis ',
#  'Nauru',
#  'Yemen',
#  'Georgia',
#  'Seychelles ',
#  'Rwanda',
#  'Saudi Arabia',
#  'Georgia',
#  'Malta',
#  'South Korea',
#  ...]

# %%
sn.lmplot(x='Unit Cost',y='Total Profit',data=sales_data,height=5,aspect=1,hue='Sales Channel',logx=False,truncate=True,ci=100,y_jitter=2.2,scatter=True,fit_reg=True,markers=['o','x'])

# %% [markdown]
# ### From the above LM plot, we can infer that profit keeps on increasing with increase in unit cost.

# %% [markdown]
# # KDE Plot

# %%
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'])

# %%
sn.kdeplot(x='Order Date',y='Units Sold',data=sales_data,shade=True,cut=3)
# Out:
# <ipython-input-90-3e7f08ef35e3>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sn.kdeplot(x='Order Date',y='Units Sold',data=sales_data,shade=True,cut=3)
# <Axes: xlabel='Order Date', ylabel='Units Sold'>

# %%
sales_data['Ship Date'] = pd.to_datetime(sales_data['Ship Date'])

# %%
sn.kdeplot(x='Ship Date',y='Total Cost',data=sales_data,shade=True,cut=2)
# Out:
# <ipython-input-92-4545e61a0963>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sn.kdeplot(x='Ship Date',y='Total Cost',data=sales_data,shade=True,cut=2)
# <Axes: xlabel='Ship Date', ylabel='Total Cost'>

# %% [markdown]
# # Violin Plot

# %%
pal = sn.cubehelix_palette(2, rot=-.5, dark=.3)

# %%
sn.violinplot(data=sales_data,palette=pal,inner="points")
list_a = list(range(12))
mp.locator_params(axis='y',nbins=10)
mp.locator_params(axis='x',nbins=10)
# Out:
# <ipython-input-94-5c87db5b1579>:1: UserWarning:
# The palette list has fewer values (2) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   sn.violinplot(data=sales_data,palette=pal,inner="points")
# <ipython-input-94-5c87db5b1579>:4: UserWarning: 'set_params()' not defined for locator of type <class 'matplotlib.category.StrCategoryLocator'>
#   mp.locator_params(axis='x',nbins=10)

# %%
sales_data.head()
# Out:
#           Order Date Order Priority  Ship Date        Item Type  \
# Order ID
# 292494523 2011-01-27              L 2011-02-12  Office Supplies
# 361825549 2015-12-28              C 2016-01-23        Beverages
# 141515767 2011-01-13              C 2011-02-01       Vegetables
# 500364005 2012-09-11              C 2012-10-06        Household
# 127481591 2015-10-27              C 2015-12-05        Beverages
#
#                                  Region                           Country  \
# Order ID
# 292494523            Sub-Saharan Africa                              Chad
# 361825549                        Europe                            Latvia
# 141515767  Middle East and North Africa                          Pakistan
# 500364005            Sub-Saharan Africa  Democratic Republic of the Congo
# 127481591                        Europe                    Czech Republic
#
#           Sales Channel  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID
# 292494523        Online        4484      651.21     524.96         167.94
# 361825549        Online        1075       47.45      31.79      308633.52
# 141515767       Offline        6515      154.06      90.93       51008.75
# 500364005        Online        7683      668.27     502.54       41369.22
# 127481591        Online        3491       47.45      31.79       17556.50
#
#            Total Cost  Total Profit
# Order ID
# 292494523  2353920.64     566105.00
# 361825549    34174.25      16834.50
# 141515767   592408.95     411291.95
# 500364005  3861014.82    1273303.59
# 127481591   110978.89      54669.06

# %%
sales_data.plot(x='Unit Cost', y='Total Profit', kind='bar')
mp.xticks(rotation=90,fontsize=10)
mp.yticks(rotation=90,fontsize=10)
mp.locator_params(axis='x',nbins=40)
mp.locator_params(axis='y',nbins=30)
mp.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
pd.pivot_table(index='Order Date',values='Total Revenue',data=sales_data,aggfunc='count').plot(kind='line',color='blue',legend=False)
mp.ylabel('Total Revenue')
mp.yticks(fontsize=12,color='green')
mp.xticks(fontsize=12,color='purple')
mp.title('Revenue generated per Order Date',fontsize=16,color='grey')
# Out:
# Text(0.5, 1.0, 'Revenue generated per Order Date')

# %% [markdown]
# ### Total revenue remains constant for every year from 2010 to 2017.
